# %% [markdown]
# <a href="https://colab.research.google.com/github/Ofiregev/Final_Project-FetalCns/blob/main/ofir's_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import pandas as pd
import torch.nn.functional as F
from sklearn.model_selection import KFold
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

print("Part 1 has done")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Part 1 has done

# %%
from sklearn.preprocessing import StandardScaler

class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.data_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

        # Initialize StandardScaler for normalization
        self.scaler = StandardScaler()
        self.labels = self.data_frame.iloc[:, 2].values.reshape(-1, 1)
        self.labels = self.scaler.fit_transform(self.labels)

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.data_frame.iloc[idx, 0])
        image = Image.open(img_name)
        if self.transform:
            image = self.transform(image)

        # Get the normalized label
        label = self.labels[idx]

        return image, label

# %%
# Determine the available hardware (CPU or GPU) and set the PyTorch device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# Read the list of images from the CSV file
train_csv = "/content/drive/MyDrive/FinalProject/training_set_pixel_size_and_HC.csv"
train_csv_df = pd.read_csv(train_csv)

# %%
train_csv_df.head()
len(train_csv_df)
# Out:
# 999

# %%
# Part 3: Define Transforms and Create Dataset

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
])
train_dataset = CustomDataset(csv_file="/content/drive/MyDrive/FinalProject/training_set_pixel_size_and_HC.csv",
                              root_dir="/content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/",
                              transform=transform)

# %%
# Part 4: Create DataLoader
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# Part 5: Define Model
class Model(nn.Module):
    def __init__(self, input_channels=1, input_size=64):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        conv_output_size = input_size // 2 // 2 // 2 // 2  # Adjusted for additional pooling layers
        self.fc1 = nn.Linear(512 * conv_output_size * conv_output_size, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, 1)
        self.dropout = nn.Dropout(0.3)
        self.batchnorm1 = nn.BatchNorm2d(64)
        self.batchnorm2 = nn.BatchNorm2d(128)
        self.batchnorm3 = nn.BatchNorm2d(256)
        self.batchnorm4 = nn.BatchNorm2d(512)

    def forward(self, x):
        x = self.pool(F.relu(self.batchnorm1(self.conv1(x))))
        x = self.pool(F.relu(self.batchnorm2(self.conv2(x))))
        x = self.pool(F.relu(self.batchnorm3(self.conv3(x))))
        x = self.pool(F.relu(self.batchnorm4(self.conv4(x))))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        return x

# %%
model = Model(input_channels=1, input_size=64)
model.to(device)
# Out:
# Model(
#   (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=8192, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (batchnorm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
# Part 6: Define Training Parameters and Optimizer
learning_rate = 0.001
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)

# %%
def train(model, train_loader, optimizer, criterion, epochs, device):
    model.to(device)
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for inputs, labels in train_loader:
            inputs = inputs.float().to(device)
            labels = labels.float().unsqueeze(1).to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch + 1}, Loss: {epoch_loss:.4f}")

# %%
def evaluate(model, val_loader, criterion, device):
    model.eval()
    val_losses = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = inputs.float().to(device)
            labels = labels.float().unsqueeze(1).to(device)

            outputs = model(inputs)
            val_loss = criterion(outputs, labels)
            val_losses.append(val_loss.item())

    fold_avg_val_loss = np.mean(val_losses)
    return fold_avg_val_loss

# %%
k = 3
kf = KFold(n_splits=k, shuffle=True, random_state=42)
evaluation_metrics = []
epochs = 8

for fold_idx, (train_idx, val_idx) in enumerate(kf.split(train_dataset)):
    print(f"Fold {fold_idx + 1}")
    print("=========")

    train_data_fold = [train_dataset[i] for i in train_idx]
    val_data_fold = [train_dataset[i] for i in val_idx]

    train_loader_fold = DataLoader(train_data_fold, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader_fold = DataLoader(val_data_fold, batch_size=batch_size, num_workers=4)

    train(model, train_loader_fold, optimizer, criterion, epochs, device)
    fold_avg_val_loss = evaluate(model, val_loader_fold, criterion, device)
    evaluation_metrics.append(fold_avg_val_loss)

    print(f"Fold {fold_idx + 1} Validation Loss: {fold_avg_val_loss:.4f}")
    print("=========")

average_metric = np.mean(evaluation_metrics)
print("Average Evaluation Metric:", average_metric)
# Out:
# Fold 1
# =========
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([8, 1, 1])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([2, 1, 1])) that is different to the input size (torch.Size([2, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1, Loss: 1.6999
# Epoch 2, Loss: 1.0179
# Epoch 3, Loss: 1.0164
# Epoch 4, Loss: 1.0158
# Epoch 5, Loss: 1.0294
# Epoch 6, Loss: 1.0271
# Epoch 7, Loss: 1.0124
# Epoch 8, Loss: 1.0295
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([5, 1, 1])) that is different to the input size (torch.Size([5, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Fold 1 Validation Loss: 1.0085
# =========
# Fold 2
# =========
# Epoch 1, Loss: 0.9465
# Epoch 2, Loss: 0.9382
# Epoch 3, Loss: 0.9545
# Epoch 4, Loss: 0.9509
# Epoch 5, Loss: 0.9646
# Epoch 6, Loss: 0.9480
# Epoch 7, Loss: 0.9536
# Epoch 8, Loss: 0.9452
# Fold 2 Validation Loss: 1.1481
# =========
# Fold 3
# =========
# Epoch 1, Loss: 1.0370
# Epoch 2, Loss: 1.0729
# Epoch 3, Loss: 1.0482
# Epoch 4, Loss: 1.0325
# Epoch 5, Loss: 1.0339
# Epoch 6, Loss: 1.0367
# Epoch 7, Loss: 1.0326
# Epoch 8, Loss: 1.0588
# Fold 3 Validation Loss: 0.9562
# =========
# Average Evaluation Metric: 1.037597365390938

# %%
# Part 8: Save the trained model
model_path = "/content/drive/MyDrive/FinalProject/trained_model.pth"
torch.save(model.state_dict(), model_path)
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
# # Load the trained model
model_path = "/content/drive/MyDrive/FinalProject/trained_model.pth"
model = Model(input_channels=1, input_size=64)
model.load_state_dict(torch.load(model_path))
model.eval()
# Out:
# Model(
#   (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=8192, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (batchnorm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def inverse_normalize(predicted, normalization_params):
    """
    Apply inverse normalization to predicted values.

    Args:
    - predicted: Predicted values after normalization
    - normalization_params: Parameters used for normalization (e.g., mean, std)

    Returns:
    - Predicted values in the original scale
    """
    # Apply inverse normalization based on the normalization parameters
    # For example, if mean and std were used for normalization:
    mean = normalization_params['mean']
    std = normalization_params['std']
    predicted_original_scale = predicted * std + mean

    return predicted_original_scale.item()

# %%
scaler =train_dataset.scaler
# Store mean and standard deviation in normalization_params
normalization_params = {
    'mean': scaler.mean_,
    'std': scaler.scale_
}

# %%
def predict_head_circumference(image_path, model, normalization_params):
    # Open and preprocess the new image
    transform = transforms.Compose([
        transforms.Resize((64, 64)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.ToTensor()
    ])
    image = Image.open(image_path)
    image_tensor = transform(image).unsqueeze(0)  # Add batch dimension

    # Make prediction
    with torch.no_grad():
        output = model(image_tensor.float())

    # Apply inverse normalization
    predicted_circumference_normalized = output.item()
    predicted_circumference_original_scale = inverse_normalize(predicted_circumference_normalized, normalization_params)

    return predicted_circumference_original_scale  # Return the predicted head circumference in the original scale

# %%
# Choose 10 random indices from the dataset
num_images_to_test = 500
random_indices = np.random.choice(len(train_csv_df), size=num_images_to_test, replace=False)
# Initialize a list to store the absolute errors
absolute_errors = []

# Loop through the selected images
for idx in random_indices:
    image_path = os.path.join("/content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/", train_csv_df.iloc[idx, 0])
    ground_truth_circumference = train_csv_df.iloc[idx, 2]  # Assuming the third column contains the head circumference labels

    # Call the function to predict head circumference from the image
    predicted_circumference = predict_head_circumference(image_path, model, normalization_params)

    # Calculate the absolute error and add it to the list
    absolute_error = abs(predicted_circumference - ground_truth_circumference)
    absolute_errors.append(absolute_error)

    # Print the predicted and ground truth head circumferences
    print("Image:", image_path)
    print("Predicted Head Circumference:", predicted_circumference)
    print("Ground Truth Head Circumference:", ground_truth_circumference)
    print("Absolute Error:", absolute_error)
    print("==============================================")

# Calculate the average absolute error
average_absolute_error = sum(absolute_errors) / len(absolute_errors)
print("Average Absolute Error:", average_absolute_error)
# Out:
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/490_2HC.png
# Predicted Head Circumference: 175.5708197358634
# Ground Truth Head Circumference: 191.9
# Absolute Error: 16.329180264136596
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/776_HC.png
# Predicted Head Circumference: 175.4135888950065
# Ground Truth Head Circumference: 289.2
# Absolute Error: 113.78641110499348
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/657_2HC.png
# Predicted Head Circumference: 175.41418345126792
# Ground Truth Head Circumference: 231.2
# Absolute Error: 55.78581654873207
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/532_2HC.png
# Predicted Head Circumference: 175.3994536601939
# Ground Truth Head Circumference: 185.12
# Absolute Error: 9.720546339806106
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/009_HC.png
# Predicted Head Circumference: 174.81529988494998
# Ground Truth Head Circumference: 62.31
# Absolute Error: 112.50529988494998
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/512_HC.png
# Predicted Head Circumference: 175.41904101967663
# Ground Truth Head Circumference: 180.2
# Absolute Error: 4.780958980323362
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/248_HC.png
# Predicted Head Circumference: 175.427062424675
# Ground Truth Head Circumference: 170.35
# Absolute Error: 5.077062424675006
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/766_HC.png
# Predicted Head Circumference: 175.38056908517183
# Ground Truth Head Circumference: 288.9
# Absolute Error: 113.51943091482815
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/609_2HC.png
# Predicted Head Circumference: 175.3859111585961
# Ground Truth Head Circumference: 197.72
# Absolute Error: 22.33408884140391
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/027_HC.png
# Predicted Head Circumference: 175.41013896163858
# Ground Truth Head Circumference: 65.75
# Absolute Error: 109.66013896163858
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/583_2HC.png
# Predicted Head Circumference: 175.5048497565738
# Ground Truth Head Circumference: 182.99
# Absolute Error: 7.4851502434262045
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/690_2HC.png
# Predicted Head Circumference: 175.5328877269905
# Ground Truth Head Circumference: 263.5
# Absolute Error: 87.96711227300949
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/655_HC.png
# Predicted Head Circumference: 175.36559263589413
# Ground Truth Head Circumference: 192.6
# Absolute Error: 17.234407364105863
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/220_2HC.png
# Predicted Head Circumference: 175.68766596250092
# Ground Truth Head Circumference: 158.95
# Absolute Error: 16.737665962500927
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/417_HC.png
# Predicted Head Circumference: 175.37091878804483
# Ground Truth Head Circumference: 169.84
# Absolute Error: 5.530918788044829
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/645_HC.png
# Predicted Head Circumference: 175.3845025512638
# Ground Truth Head Circumference: 194.6
# Absolute Error: 19.215497448736187
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/349_HC.png
# Predicted Head Circumference: 175.41241959292336
# Ground Truth Head Circumference: 165.24
# Absolute Error: 10.172419592923347
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/489_HC.png
# Predicted Head Circumference: 175.38948621372836
# Ground Truth Head Circumference: 176.36
# Absolute Error: 0.9705137862716526
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/436_HC.png
# Predicted Head Circumference: 175.3999463081509
# Ground Truth Head Circumference: 173.3
# Absolute Error: 2.0999463081508907
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/066_2HC.png
# Predicted Head Circumference: 175.3669761459517
# Ground Truth Head Circumference: 81.44
# Absolute Error: 93.9269761459517
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/479_HC.png
# Predicted Head Circumference: 175.42243808469343
# Ground Truth Head Circumference: 177.8
# Absolute Error: 2.377561915306586
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/615_HC.png
# Predicted Head Circumference: 175.3666501852213
# Ground Truth Head Circumference: 178.15
# Absolute Error: 2.783349814778717
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/365_HC.png
# Predicted Head Circumference: 175.39664580383516
# Ground Truth Head Circumference: 174.79
# Absolute Error: 0.6066458038351641
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/510_HC.png
# Predicted Head Circumference: 175.39042040356958
# Ground Truth Head Circumference: 179.59
# Absolute Error: 4.199579596430425
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/754_HC.png
# Predicted Head Circumference: 175.38885300887924
# Ground Truth Head Circumference: 291.3
# Absolute Error: 115.91114699112077
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/707_HC.png
# Predicted Head Circumference: 175.48338435526173
# Ground Truth Head Circumference: 261.2
# Absolute Error: 85.71661564473825
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/072_HC.png
# Predicted Head Circumference: 175.49914981910382
# Ground Truth Head Circumference: 76.41
# Absolute Error: 99.08914981910382
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/794_HC.png
# Predicted Head Circumference: 175.42433295931966
# Ground Truth Head Circumference: 308.5
# Absolute Error: 133.07566704068034
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/677_HC.png
# Predicted Head Circumference: 175.3696276456812
# Ground Truth Head Circumference: 245.3
# Absolute Error: 69.93037235431882
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/198_2HC.png
# Predicted Head Circumference: 175.36856280416765
# Ground Truth Head Circumference: 155.34
# Absolute Error: 20.02856280416765
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/194_HC.png
# Predicted Head Circumference: 175.36690091489572
# Ground Truth Head Circumference: 150.37
# Absolute Error: 24.99690091489572
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/623_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 196.0
# Absolute Error: 20.302162045206074
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/462_2HC.png
# Predicted Head Circumference: 175.56714544622838
# Ground Truth Head Circumference: 168.55
# Absolute Error: 7.017145446228369
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/123_HC.png
# Predicted Head Circumference: 175.59562325701918
# Ground Truth Head Circumference: 92.36
# Absolute Error: 83.23562325701918
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/252_HC.png
# Predicted Head Circumference: 175.46303028315123
# Ground Truth Head Circumference: 169.4
# Absolute Error: 6.063030283151221
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/146_HC.png
# Predicted Head Circumference: 175.39020145567406
# Ground Truth Head Circumference: 99.7
# Absolute Error: 75.69020145567406
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/077_HC.png
# Predicted Head Circumference: 175.94084095007972
# Ground Truth Head Circumference: 75.95
# Absolute Error: 99.99084095007971
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/608_HC.png
# Predicted Head Circumference: 175.36636214386
# Ground Truth Head Circumference: 187.2
# Absolute Error: 11.833637856140001
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/364_2HC.png
# Predicted Head Circumference: 175.63584112324375
# Ground Truth Head Circumference: 173.2
# Absolute Error: 2.435841123243762
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/249_HC.png
# Predicted Head Circumference: 175.51728609426868
# Ground Truth Head Circumference: 166.94
# Absolute Error: 8.577286094268686
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/750_HC.png
# Predicted Head Circumference: 175.4170519543099
# Ground Truth Head Circumference: 282.8
# Absolute Error: 107.38294804569011
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/805_HC.png
# Predicted Head Circumference: 175.39990911800044
# Ground Truth Head Circumference: 330.7
# Absolute Error: 155.30009088199955
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/725_HC.png
# Predicted Head Circumference: 175.60349711678018
# Ground Truth Head Circumference: 287.15
# Absolute Error: 111.5465028832198
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/632_HC.png
# Predicted Head Circumference: 175.4326985555143
# Ground Truth Head Circumference: 197.9
# Absolute Error: 22.467301444485713
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/710_HC.png
# Predicted Head Circumference: 175.42971216212612
# Ground Truth Head Circumference: 283.8
# Absolute Error: 108.37028783787389
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/479_2HC.png
# Predicted Head Circumference: 175.39008496299692
# Ground Truth Head Circumference: 175.0
# Absolute Error: 0.39008496299692297
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/699_HC.png
# Predicted Head Circumference: 175.41882201101288
# Ground Truth Head Circumference: 259.3
# Absolute Error: 83.88117798898713
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/399_HC.png
# Predicted Head Circumference: 175.36825191395576
# Ground Truth Head Circumference: 173.96
# Absolute Error: 1.4082519139557519
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/420_HC.png
# Predicted Head Circumference: 175.36958553330496
# Ground Truth Head Circumference: 171.5
# Absolute Error: 3.8695855333049565
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/317_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 163.9
# Absolute Error: 11.79783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/790_HC.png
# Predicted Head Circumference: 175.39691780238647
# Ground Truth Head Circumference: 327.5
# Absolute Error: 152.10308219761353
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/748_HC.png
# Predicted Head Circumference: 175.39564963040988
# Ground Truth Head Circumference: 281.74
# Absolute Error: 106.34435036959013
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/064_HC.png
# Predicted Head Circumference: 175.41783683663536
# Ground Truth Head Circumference: 77.75
# Absolute Error: 97.66783683663536
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/203_4HC.png
# Predicted Head Circumference: 175.4091264415622
# Ground Truth Head Circumference: 156.4
# Absolute Error: 19.009126441562188
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/226_HC.png
# Predicted Head Circumference: 175.60887947953407
# Ground Truth Head Circumference: 169.48
# Absolute Error: 6.128879479534078
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/104_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 84.39
# Absolute Error: 91.30783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/093_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 79.04
# Absolute Error: 96.65783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/292_HC.png
# Predicted Head Circumference: 175.6839656640679
# Ground Truth Head Circumference: 164.4
# Absolute Error: 11.283965664067892
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/501_HC.png
# Predicted Head Circumference: 175.39439245748105
# Ground Truth Head Circumference: 173.3
# Absolute Error: 2.0943924574810353
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/288_HC.png
# Predicted Head Circumference: 175.38285032413881
# Ground Truth Head Circumference: 175.0
# Absolute Error: 0.3828503241388148
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/099_HC.png
# Predicted Head Circumference: 174.75389195821674
# Ground Truth Head Circumference: 75.3
# Absolute Error: 99.45389195821674
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/392_2HC.png
# Predicted Head Circumference: 175.17696328130376
# Ground Truth Head Circumference: 174.99
# Absolute Error: 0.18696328130374695
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/545_2HC.png
# Predicted Head Circumference: 175.42575493566025
# Ground Truth Head Circumference: 181.52
# Absolute Error: 6.094245064339759
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/253_HC.png
# Predicted Head Circumference: 175.39155397393958
# Ground Truth Head Circumference: 166.89
# Absolute Error: 8.501553973939593
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/023_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 67.9
# Absolute Error: 107.79783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/642_HC.png
# Predicted Head Circumference: 175.36566823155943
# Ground Truth Head Circumference: 212.86
# Absolute Error: 37.49433176844059
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/508_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 174.6
# Absolute Error: 1.0978379547939312
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/443_HC.png
# Predicted Head Circumference: 175.42778556648923
# Ground Truth Head Circumference: 183.12
# Absolute Error: 7.69221443351077
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/133_HC.png
# Predicted Head Circumference: 175.71947921933378
# Ground Truth Head Circumference: 103.85
# Absolute Error: 71.86947921933378
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/022_2HC.png
# Predicted Head Circumference: 175.69560180584597
# Ground Truth Head Circumference: 64.45
# Absolute Error: 111.24560180584596
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/284_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 167.73
# Absolute Error: 7.967837954793936
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/022_HC.png
# Predicted Head Circumference: 175.08997722091843
# Ground Truth Head Circumference: 65.8
# Absolute Error: 109.28997722091843
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/334_HC.png
# Predicted Head Circumference: 175.42322916537728
# Ground Truth Head Circumference: 177.4
# Absolute Error: 1.9767708346227266
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/783_3HC.png
# Predicted Head Circumference: 175.3789982874612
# Ground Truth Head Circumference: 314.32
# Absolute Error: 138.9410017125388
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/566_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 185.41
# Absolute Error: 9.712162045206071
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/416_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 160.6
# Absolute Error: 15.097837954793931
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/773_2HC.png
# Predicted Head Circumference: 175.41023181547826
# Ground Truth Head Circumference: 292.2
# Absolute Error: 116.78976818452173
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/020_HC.png
# Predicted Head Circumference: 175.24685870528032
# Ground Truth Head Circumference: 68.41
# Absolute Error: 106.83685870528032
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/312_2HC.png
# Predicted Head Circumference: 175.64335013061373
# Ground Truth Head Circumference: 170.6
# Absolute Error: 5.043350130613732
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/729_HC.png
# Predicted Head Circumference: 175.40607782151707
# Ground Truth Head Circumference: 278.1
# Absolute Error: 102.69392217848295
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/407_HC.png
# Predicted Head Circumference: 175.45709966951935
# Ground Truth Head Circumference: 177.02
# Absolute Error: 1.5629003304806588
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/062_HC.png
# Predicted Head Circumference: 175.15128573084425
# Ground Truth Head Circumference: 74.6
# Absolute Error: 100.55128573084426
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/596_HC.png
# Predicted Head Circumference: 175.4394147806903
# Ground Truth Head Circumference: 175.76
# Absolute Error: 0.32058521930969164
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/687_HC.png
# Predicted Head Circumference: 175.3788074752514
# Ground Truth Head Circumference: 249.5
# Absolute Error: 74.12119252474861
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/189_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 125.25
# Absolute Error: 50.447837954793926
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/003_HC.png
# Predicted Head Circumference: 175.36555605342588
# Ground Truth Head Circumference: 69.0
# Absolute Error: 106.36555605342588
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/037_HC.png
# Predicted Head Circumference: 175.50282240722868
# Ground Truth Head Circumference: 78.5
# Absolute Error: 97.00282240722868
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/379_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 169.68
# Absolute Error: 6.017837954793919
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/370_HC.png
# Predicted Head Circumference: 175.3927292920765
# Ground Truth Head Circumference: 172.0
# Absolute Error: 3.3927292920764955
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/761_HC.png
# Predicted Head Circumference: 175.36501163094573
# Ground Truth Head Circumference: 294.7
# Absolute Error: 119.33498836905426
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/567_2HC.png
# Predicted Head Circumference: 175.46719108315304
# Ground Truth Head Circumference: 172.78
# Absolute Error: 2.6871910831530386
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/678_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 231.9
# Absolute Error: 56.20216204520608
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/082_2HC.png
# Predicted Head Circumference: 175.52924224149163
# Ground Truth Head Circumference: 65.71
# Absolute Error: 109.81924224149164
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/056_HC.png
# Predicted Head Circumference: 174.77769790827818
# Ground Truth Head Circumference: 69.86
# Absolute Error: 104.91769790827819
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/108_3HC.png
# Predicted Head Circumference: 175.15196457262633
# Ground Truth Head Circumference: 83.42
# Absolute Error: 91.73196457262632
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/440_2HC.png
# Predicted Head Circumference: 175.36911543035745
# Ground Truth Head Circumference: 165.8
# Absolute Error: 9.569115430357442
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/332_HC.png
# Predicted Head Circumference: 175.37697640725585
# Ground Truth Head Circumference: 169.3
# Absolute Error: 6.076976407255842
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/278_HC.png
# Predicted Head Circumference: 175.37049723890487
# Ground Truth Head Circumference: 178.0
# Absolute Error: 2.629502761095125
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/745_HC.png
# Predicted Head Circumference: 175.49536104214292
# Ground Truth Head Circumference: 302.8
# Absolute Error: 127.3046389578571
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/665_HC.png
# Predicted Head Circumference: 175.47425611791002
# Ground Truth Head Circumference: 226.9
# Absolute Error: 51.42574388208999
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/210_2HC.png
# Predicted Head Circumference: 175.3649816114452
# Ground Truth Head Circumference: 163.26
# Absolute Error: 12.104981611445197
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/681_HC.png
# Predicted Head Circumference: 175.43584416163804
# Ground Truth Head Circumference: 231.27
# Absolute Error: 55.834155838361966
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/507_HC.png
# Predicted Head Circumference: 175.47258329035853
# Ground Truth Head Circumference: 166.73
# Absolute Error: 8.742583290358539
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/166_HC.png
# Predicted Head Circumference: 175.36771812591405
# Ground Truth Head Circumference: 116.75
# Absolute Error: 58.61771812591405
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/588_2HC.png
# Predicted Head Circumference: 175.40275853982146
# Ground Truth Head Circumference: 172.13
# Absolute Error: 3.272758539821467
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/648_HC.png
# Predicted Head Circumference: 175.58037347228935
# Ground Truth Head Circumference: 223.5
# Absolute Error: 47.91962652771065
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/795_HC.png
# Predicted Head Circumference: 175.50289180453555
# Ground Truth Head Circumference: 327.57
# Absolute Error: 152.06710819546444
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/541_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 167.4
# Absolute Error: 8.29783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/216_HC.png
# Predicted Head Circumference: 175.54693089795032
# Ground Truth Head Circumference: 164.8
# Absolute Error: 10.746930897950307
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/484_HC.png
# Predicted Head Circumference: 175.6830222982255
# Ground Truth Head Circumference: 179.66
# Absolute Error: 3.9769777017745014
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/028_HC.png
# Predicted Head Circumference: 176.9731948010782
# Ground Truth Head Circumference: 70.0
# Absolute Error: 106.9731948010782
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/500_HC.png
# Predicted Head Circumference: 175.37461155121863
# Ground Truth Head Circumference: 177.58
# Absolute Error: 2.2053884487813775
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/641_HC.png
# Predicted Head Circumference: 175.41162608151072
# Ground Truth Head Circumference: 212.1
# Absolute Error: 36.688373918489276
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/223_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 172.09
# Absolute Error: 3.607837954793922
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/209_HC.png
# Predicted Head Circumference: 175.3984073529874
# Ground Truth Head Circumference: 163.1
# Absolute Error: 12.298407352987397
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/178_2HC.png
# Predicted Head Circumference: 174.92339955942361
# Ground Truth Head Circumference: 100.7
# Absolute Error: 74.22339955942361
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/082_HC.png
# Predicted Head Circumference: 175.36667832090703
# Ground Truth Head Circumference: 73.98
# Absolute Error: 101.38667832090702
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/016_HC.png
# Predicted Head Circumference: 175.39150602781424
# Ground Truth Head Circumference: 65.05
# Absolute Error: 110.34150602781425
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/487_HC.png
# Predicted Head Circumference: 175.40514563702712
# Ground Truth Head Circumference: 176.53
# Absolute Error: 1.1248543629728829
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/235_HC.png
# Predicted Head Circumference: 175.4431301496418
# Ground Truth Head Circumference: 170.78
# Absolute Error: 4.663130149641802
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/777_HC.png
# Predicted Head Circumference: 175.53753819730653
# Ground Truth Head Circumference: 300.4
# Absolute Error: 124.86246180269345
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/335_HC.png
# Predicted Head Circumference: 175.44839911889778
# Ground Truth Head Circumference: 170.84
# Absolute Error: 4.608399118897779
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/478_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 184.1
# Absolute Error: 8.402162045206069
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/088_2HC.png
# Predicted Head Circumference: 175.84478729902594
# Ground Truth Head Circumference: 95.71
# Absolute Error: 80.13478729902594
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/340_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 175.09
# Absolute Error: 0.6078379547939221
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/157_HC.png
# Predicted Head Circumference: 175.61332443173112
# Ground Truth Head Circumference: 105.5
# Absolute Error: 70.11332443173112
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/570_2HC.png
# Predicted Head Circumference: 175.50898600621485
# Ground Truth Head Circumference: 188.97
# Absolute Error: 13.461013993785144
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/359_2HC.png
# Predicted Head Circumference: 175.37867828201635
# Ground Truth Head Circumference: 178.04
# Absolute Error: 2.6613217179836397
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/437_2HC.png
# Predicted Head Circumference: 175.37455783211243
# Ground Truth Head Circumference: 174.63
# Absolute Error: 0.7445578321124344
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/624_HC.png
# Predicted Head Circumference: 175.40552300767135
# Ground Truth Head Circumference: 197.77
# Absolute Error: 22.36447699232866
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/215_HC.png
# Predicted Head Circumference: 175.37223277925906
# Ground Truth Head Circumference: 154.6
# Absolute Error: 20.77223277925907
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/312_HC.png
# Predicted Head Circumference: 175.44818472861874
# Ground Truth Head Circumference: 174.8
# Absolute Error: 0.6481847286187303
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/382_2HC.png
# Predicted Head Circumference: 175.43274510397057
# Ground Truth Head Circumference: 165.74
# Absolute Error: 9.692745103970566
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/781_HC.png
# Predicted Head Circumference: 175.59159821322015
# Ground Truth Head Circumference: 307.7
# Absolute Error: 132.10840178677984
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/492_HC.png
# Predicted Head Circumference: 175.37432423907595
# Ground Truth Head Circumference: 170.41
# Absolute Error: 4.96432423907595
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/534_HC.png
# Predicted Head Circumference: 175.41762973854267
# Ground Truth Head Circumference: 176.16
# Absolute Error: 0.7423702614573244
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/517_HC.png
# Predicted Head Circumference: 175.40936307300967
# Ground Truth Head Circumference: 176.9
# Absolute Error: 1.4906369269903337
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/734_HC.png
# Predicted Head Circumference: 175.36577062600958
# Ground Truth Head Circumference: 274.87
# Absolute Error: 99.50422937399043
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/142_HC.png
# Predicted Head Circumference: 175.0497538855541
# Ground Truth Head Circumference: 107.99
# Absolute Error: 67.05975388555412
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/345_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 164.97
# Absolute Error: 10.727837954793927
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/325_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 165.9
# Absolute Error: 9.79783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/682_HC.png
# Predicted Head Circumference: 175.40847050939894
# Ground Truth Head Circumference: 238.51
# Absolute Error: 63.10152949060105
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/590_HC.png
# Predicted Head Circumference: 175.61179987863568
# Ground Truth Head Circumference: 179.04
# Absolute Error: 3.4282001213643127
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/685_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 241.7
# Absolute Error: 66.00216204520606
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/300_2HC.png
# Predicted Head Circumference: 175.63689970563064
# Ground Truth Head Circumference: 183.73
# Absolute Error: 8.09310029436935
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/318_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 163.65
# Absolute Error: 12.04783795479392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/628_HC.png
# Predicted Head Circumference: 175.365595917378
# Ground Truth Head Circumference: 182.6
# Absolute Error: 7.234404082622007
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/093_2HC.png
# Predicted Head Circumference: 175.06162994026351
# Ground Truth Head Circumference: 76.16
# Absolute Error: 98.90162994026352
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/433_HC.png
# Predicted Head Circumference: 175.41710579495256
# Ground Truth Head Circumference: 173.3
# Absolute Error: 2.1171057949525505
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/036_HC.png
# Predicted Head Circumference: 175.0155828825657
# Ground Truth Head Circumference: 73.96
# Absolute Error: 101.0555828825657
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/739_HC.png
# Predicted Head Circumference: 175.38268898451554
# Ground Truth Head Circumference: 275.9
# Absolute Error: 100.51731101548444
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/613_3HC.png
# Predicted Head Circumference: 175.40827836028828
# Ground Truth Head Circumference: 169.4
# Absolute Error: 6.008278360288273
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/763_HC.png
# Predicted Head Circumference: 175.39227796650889
# Ground Truth Head Circumference: 305.24
# Absolute Error: 129.84772203349112
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/310_HC.png
# Predicted Head Circumference: 175.37407606166676
# Ground Truth Head Circumference: 170.2
# Absolute Error: 5.174076061666767
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/450_HC.png
# Predicted Head Circumference: 175.39668092786613
# Ground Truth Head Circumference: 168.7
# Absolute Error: 6.69668092786614
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/483_HC.png
# Predicted Head Circumference: 175.49589835474137
# Ground Truth Head Circumference: 174.44
# Absolute Error: 1.0558983547413732
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/259_HC.png
# Predicted Head Circumference: 175.57750897994984
# Ground Truth Head Circumference: 171.6
# Absolute Error: 3.977508979949846
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/746_4HC.png
# Predicted Head Circumference: 175.42856376431052
# Ground Truth Head Circumference: 279.4
# Absolute Error: 103.97143623568945
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/316_HC.png
# Predicted Head Circumference: 175.39574424652793
# Ground Truth Head Circumference: 173.84
# Absolute Error: 1.5557442465279223
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/049_HC.png
# Predicted Head Circumference: 175.38586558243134
# Ground Truth Head Circumference: 69.7
# Absolute Error: 105.68586558243133
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/176_HC.png
# Predicted Head Circumference: 175.40025391687894
# Ground Truth Head Circumference: 118.17
# Absolute Error: 57.23025391687894
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/204_HC.png
# Predicted Head Circumference: 175.3865443634452
# Ground Truth Head Circumference: 149.1
# Absolute Error: 26.286544363445216
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/401_HC.png
# Predicted Head Circumference: 175.38557353036754
# Ground Truth Head Circumference: 170.08
# Absolute Error: 5.305573530367525
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/454_HC.png
# Predicted Head Circumference: 175.45057413501672
# Ground Truth Head Circumference: 169.7
# Absolute Error: 5.750574135016734
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/108_HC.png
# Predicted Head Circumference: 175.4121073658106
# Ground Truth Head Circumference: 94.8
# Absolute Error: 80.61210736581062
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/230_HC.png
# Predicted Head Circumference: 175.40500307478374
# Ground Truth Head Circumference: 158.52
# Absolute Error: 16.885003074783725
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/265_HC.png
# Predicted Head Circumference: 175.36551527795046
# Ground Truth Head Circumference: 168.92
# Absolute Error: 6.445515277950477
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/613_2HC.png
# Predicted Head Circumference: 175.6835619200163
# Ground Truth Head Circumference: 170.47
# Absolute Error: 5.2135619200163035
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/725_2HC.png
# Predicted Head Circumference: 175.38194068465833
# Ground Truth Head Circumference: 278.34
# Absolute Error: 102.95805931534164
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/564_HC.png
# Predicted Head Circumference: 175.38234145106716
# Ground Truth Head Circumference: 184.6
# Absolute Error: 9.217658548932832
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/592_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 176.33
# Absolute Error: 0.632162045206087
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/303_HC.png
# Predicted Head Circumference: 175.56086334921383
# Ground Truth Head Circumference: 171.2
# Absolute Error: 4.360863349213844
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/057_HC.png
# Predicted Head Circumference: 175.37283602537588
# Ground Truth Head Circumference: 74.61
# Absolute Error: 100.76283602537588
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/513_HC.png
# Predicted Head Circumference: 175.37254306178878
# Ground Truth Head Circumference: 178.52
# Absolute Error: 3.147456938211235
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/230_2HC.png
# Predicted Head Circumference: 175.3654887830067
# Ground Truth Head Circumference: 159.89
# Absolute Error: 15.47548878300671
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/756_2HC.png
# Predicted Head Circumference: 175.4393154854193
# Ground Truth Head Circumference: 279.2
# Absolute Error: 103.76068451458067
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/507_2HC.png
# Predicted Head Circumference: 175.48159485272845
# Ground Truth Head Circumference: 166.73
# Absolute Error: 8.75159485272846
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/529_HC.png
# Predicted Head Circumference: 175.36554383901372
# Ground Truth Head Circumference: 173.65
# Absolute Error: 1.7155438390137192
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/394_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 184.6
# Absolute Error: 8.902162045206069
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/579_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 180.44
# Absolute Error: 4.742162045206072
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/319_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 171.1
# Absolute Error: 4.597837954793931
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/730_2HC.png
# Predicted Head Circumference: 175.41615088314842
# Ground Truth Head Circumference: 296.44
# Absolute Error: 121.02384911685158
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/584_HC.png
# Predicted Head Circumference: 175.4516042778768
# Ground Truth Head Circumference: 185.6
# Absolute Error: 10.148395722123183
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/396_HC.png
# Predicted Head Circumference: 175.3714799825536
# Ground Truth Head Circumference: 173.13
# Absolute Error: 2.2414799825536136
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/405_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 177.0
# Absolute Error: 1.3021620452060745
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/276_2HC.png
# Predicted Head Circumference: 175.44362674753307
# Ground Truth Head Circumference: 182.93
# Absolute Error: 7.486373252466933
# ==============================================
# ...
# Predicted Head Circumference: 175.40899822061868
# Ground Truth Head Circumference: 215.46
# Absolute Error: 40.05100177938132
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/757_HC.png
# Predicted Head Circumference: 175.39643086664213
# Ground Truth Head Circumference: 300.0
# Absolute Error: 124.60356913335787
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/553_HC.png
# Predicted Head Circumference: 175.37204372932763
# Ground Truth Head Circumference: 186.81
# Absolute Error: 11.437956270672373
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/747_HC.png
# Predicted Head Circumference: 175.4432187497061
# Ground Truth Head Circumference: 272.8
# Absolute Error: 97.35678125029392
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/644_HC.png
# Predicted Head Circumference: 175.3680137025346
# Ground Truth Head Circumference: 209.06
# Absolute Error: 33.691986297465405
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/434_HC.png
# Predicted Head Circumference: 175.39742740467673
# Ground Truth Head Circumference: 167.99
# Absolute Error: 7.407427404676724
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/195_2HC.png
# Predicted Head Circumference: 175.38479332719498
# Ground Truth Head Circumference: 156.27
# Absolute Error: 19.114793327194974
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/482_3HC.png
# Predicted Head Circumference: 175.67192030909845
# Ground Truth Head Circumference: 171.16
# Absolute Error: 4.511920309098457
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/481_HC.png
# Predicted Head Circumference: 175.60728224764787
# Ground Truth Head Circumference: 177.85
# Absolute Error: 2.242717752352121
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/102_2HC.png
# Predicted Head Circumference: 176.32025194806528
# Ground Truth Head Circumference: 77.2
# Absolute Error: 99.12025194806527
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/136_HC.png
# Predicted Head Circumference: 175.45294482480307
# Ground Truth Head Circumference: 100.83
# Absolute Error: 74.62294482480307
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/575_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 171.79
# Absolute Error: 3.9078379547939335
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/095_HC.png
# Predicted Head Circumference: 175.67403370624262
# Ground Truth Head Circumference: 77.7
# Absolute Error: 97.97403370624262
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/679_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 242.0
# Absolute Error: 66.30216204520607
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/114_HC.png
# Predicted Head Circumference: 175.4088269757756
# Ground Truth Head Circumference: 82.33
# Absolute Error: 93.07882697577561
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/494_HC.png
# Predicted Head Circumference: 175.36562818530265
# Ground Truth Head Circumference: 183.85
# Absolute Error: 8.48437181469734
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/769_HC.png
# Predicted Head Circumference: 175.40767079962788
# Ground Truth Head Circumference: 311.82
# Absolute Error: 136.4123292003721
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/698_HC.png
# Predicted Head Circumference: 175.3734992497255
# Ground Truth Head Circumference: 273.4
# Absolute Error: 98.02650075027447
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/327_HC.png
# Predicted Head Circumference: 175.41101293017408
# Ground Truth Head Circumference: 163.11
# Absolute Error: 12.301012930174068
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/626_HC.png
# Predicted Head Circumference: 175.46172887095847
# Ground Truth Head Circumference: 196.48
# Absolute Error: 21.018271129041523
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/762_HC.png
# Predicted Head Circumference: 175.4268635910602
# Ground Truth Head Circumference: 277.6
# Absolute Error: 102.17313640893983
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/427_HC.png
# Predicted Head Circumference: 175.67681956450585
# Ground Truth Head Circumference: 183.58
# Absolute Error: 7.903180435494164
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/251_HC.png
# Predicted Head Circumference: 175.3904523068849
# Ground Truth Head Circumference: 168.32
# Absolute Error: 7.070452306884903
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/346_HC.png
# Predicted Head Circumference: 175.06433971671566
# Ground Truth Head Circumference: 171.0
# Absolute Error: 4.064339716715665
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/174_HC.png
# Predicted Head Circumference: 175.6938089002924
# Ground Truth Head Circumference: 116.6
# Absolute Error: 59.0938089002924
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/347_HC.png
# Predicted Head Circumference: 175.38668710799325
# Ground Truth Head Circumference: 164.05
# Absolute Error: 11.336687107993242
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/643_HC.png
# Predicted Head Circumference: 175.39674206069515
# Ground Truth Head Circumference: 213.6
# Absolute Error: 38.20325793930485
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/175_HC.png
# Predicted Head Circumference: 175.5121683163433
# Ground Truth Head Circumference: 121.49
# Absolute Error: 54.0221683163433
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/676_HC.png
# Predicted Head Circumference: 175.39291463514652
# Ground Truth Head Circumference: 225.4
# Absolute Error: 50.00708536485348
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/120_HC.png
# Predicted Head Circumference: 174.74459642595625
# Ground Truth Head Circumference: 88.81
# Absolute Error: 85.93459642595624
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/471_2HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 177.52
# Absolute Error: 1.8221620452060847
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/570_HC.png
# Predicted Head Circumference: 175.4219853614568
# Ground Truth Head Circumference: 189.26
# Absolute Error: 13.8380146385432
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/108_2HC.png
# Predicted Head Circumference: 175.6801722687223
# Ground Truth Head Circumference: 94.35
# Absolute Error: 81.3301722687223
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/426_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 145.19
# Absolute Error: 30.507837954793928
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/746_2HC.png
# Predicted Head Circumference: 175.53245590802143
# Ground Truth Head Circumference: 278.4
# Absolute Error: 102.86754409197854
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/703_HC.png
# Predicted Head Circumference: 175.49506376401223
# Ground Truth Head Circumference: 255.8
# Absolute Error: 80.30493623598778
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/527_HC.png
# Predicted Head Circumference: 175.69783795479393
# Ground Truth Head Circumference: 184.36
# Absolute Error: 8.662162045206088
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/066_HC.png
# Predicted Head Circumference: 175.3649707947021
# Ground Truth Head Circumference: 77.18
# Absolute Error: 98.18497079470208
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/556_HC.png
# Predicted Head Circumference: 175.4386085079515
# Ground Truth Head Circumference: 182.3
# Absolute Error: 6.8613914920485115
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/289_HC.png
# Predicted Head Circumference: 175.391562116881
# Ground Truth Head Circumference: 183.79
# Absolute Error: 8.398437883118987
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/495_2HC.png
# Predicted Head Circumference: 175.36553435917145
# Ground Truth Head Circumference: 193.1
# Absolute Error: 17.734465640828546
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/760_HC.png
# Predicted Head Circumference: 175.39211632304452
# Ground Truth Head Circumference: 292.12
# Absolute Error: 116.72788367695549
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/786_HC.png
# Predicted Head Circumference: 175.4034041413874
# Ground Truth Head Circumference: 299.97
# Absolute Error: 124.56659585861263
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/006_HC.png
# Predicted Head Circumference: 174.56494940422212
# Ground Truth Head Circumference: 67.84
# Absolute Error: 106.72494940422212
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/783_2HC.png
# Predicted Head Circumference: 175.4168669758492
# Ground Truth Head Circumference: 314.98
# Absolute Error: 139.56313302415083
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/652_HC.png
# Predicted Head Circumference: 175.42797334028808
# Ground Truth Head Circumference: 219.09
# Absolute Error: 43.66202665971193
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/625_HC.png
# Predicted Head Circumference: 175.49905271148876
# Ground Truth Head Circumference: 199.3
# Absolute Error: 23.800947288511253
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/784_HC.png
# Predicted Head Circumference: 175.4213528858263
# Ground Truth Head Circumference: 328.0
# Absolute Error: 152.5786471141737
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/463_HC.png
# Predicted Head Circumference: 175.39001471493495
# Ground Truth Head Circumference: 171.1
# Absolute Error: 4.290014714934955
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/598_HC.png
# Predicted Head Circumference: 175.46630605480155
# Ground Truth Head Circumference: 184.33
# Absolute Error: 8.863693945198463
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/340_HC.png
# Predicted Head Circumference: 175.37740518781396
# Ground Truth Head Circumference: 170.35
# Absolute Error: 5.027405187813969
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/143_HC.png
# Predicted Head Circumference: 175.41200867822184
# Ground Truth Head Circumference: 102.83
# Absolute Error: 72.58200867822184
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/191_HC.png
# Predicted Head Circumference: 175.3913188616976
# Ground Truth Head Circumference: 137.3
# Absolute Error: 38.0913188616976
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/414_HC.png
# Predicted Head Circumference: 175.64558518573372
# Ground Truth Head Circumference: 168.33
# Absolute Error: 7.31558518573371
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/182_HC.png
# Predicted Head Circumference: 175.42638072678656
# Ground Truth Head Circumference: 134.0
# Absolute Error: 41.42638072678656
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/532_HC.png
# Predicted Head Circumference: 175.38710561872222
# Ground Truth Head Circumference: 177.5
# Absolute Error: 2.1128943812777834
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/520_HC.png
# Predicted Head Circumference: 175.3780977024455
# Ground Truth Head Circumference: 174.15
# Absolute Error: 1.2280977024454955
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/700_HC.png
# Predicted Head Circumference: 175.42278191128042
# Ground Truth Head Circumference: 259.46
# Absolute Error: 84.03721808871956
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/482_2HC.png
# Predicted Head Circumference: 175.40664333056947
# Ground Truth Head Circumference: 172.89
# Absolute Error: 2.5166433305694795
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/088_HC.png
# Predicted Head Circumference: 175.38230310632053
# Ground Truth Head Circumference: 80.72
# Absolute Error: 94.66230310632054
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/533_HC.png
# Predicted Head Circumference: 175.3905551267126
# Ground Truth Head Circumference: 184.1
# Absolute Error: 8.709444873287396
# ==============================================
# Image: /content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/696_HC.png
# Predicted Head Circumference: 175.37621103152895
# Ground Truth Head Circumference: 260.57
# Absolute Error: 85.19378896847104
# ==============================================
# Average Absolute Error: 44.74759019410815

# %%
# # Path for the new image
# new_image_path = "/content/drive/MyDrive/FinalProject/Dataset/training_set/training_set/001_HC.png"
# # Call the function to predict head circumference from the new image
# predicted_circumference = predict_head_circumference(new_image_path, model)
# print("Predicted Head Circumference:", predicted_circumference)
